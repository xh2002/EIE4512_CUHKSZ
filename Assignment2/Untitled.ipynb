# %%
import cv2
import numpy as np
import math
import matplotlib.pyplot as plt

def estimateWhiteNoise(img_path):
    # Read the image
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    
    # Normalize the image to range [0, 1]
    img = img / 255.0
    
    # Apply Gaussian blur to get a smoothed version of the image
    smoothed_img = cv2.GaussianBlur(img, (7, 7), 1.5)
    
    # Calculate the difference between the degraded image and the smoothed image
    difference = img - smoothed_img
    
    # Estimate the standard deviation of the noise
    noise_std = np.std(difference)
   
    return noise_std

# Example usage:
img_path = 'pro2_satellite_1_degraded.tiff'
noise_std = estimateWhiteNoise(img_path)
print(f"Estimated noise standard deviation: {noise_std}")
# Out:
# Estimated noise standard deviation: 88.92412630274356
